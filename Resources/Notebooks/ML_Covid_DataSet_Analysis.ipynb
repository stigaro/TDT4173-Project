# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
import plotly.graph_objects as go
import plotly.graph_objs as go
import re
import plotly.express as px
from collections import Counter
from wordcloud import WordCloud

# %% [markdown]
# **Read data**

# %%
train=pd.read_csv("/content/drive/My Drive/DataSets/archive/Corona_NLP_train.csv",encoding='latin1');
test=pd.read_csv("/content/drive/My Drive/DataSets/archive/Corona_NLP_test.csv",encoding='latin1');

df = train.append(test, sort = False)

df.head()
# Out:
#    UserName  ...           Sentiment
# 0      3799  ...             Neutral
# 1      3800  ...            Positive
# 2      3801  ...            Positive
# 3      3802  ...            Positive
# 4      3803  ...  Extremely Negative
#
# [5 rows x 6 columns]

# %% [markdown]
# **Data structure**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44955 entries, 0 to 3797
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       44955 non-null  int64
#  1   ScreenName     44955 non-null  int64
#  2   Location       35531 non-null  object
#  3   TweetAt        44955 non-null  object
#  4   OriginalTweet  44955 non-null  object
#  5   Sentiment      44955 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.4+ MB

# %% [markdown]
# **Sentiment Class Distrubution**

# %%
df_dist = df['Sentiment'].value_counts()

fig = go.Figure([go.Bar(x=df_dist.index, y=df_dist.values)])
fig.update_layout(width=800, showlegend=False, xaxis_title="Sentiments", yaxis_title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff796587-4700-451a-809a-fedf24afe486" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff796587-4700-451a-809a-fedf24afe486")) {
#                     Plotly.newPlot(
#                         'ff796587-4700-451a-809a-fedf24afe486',
#                         [{"type": "bar", "x": ["Positive", "Negative", "Neutral", "Extremely Positive", "Extremely Negative"], "y": [12369, 10958, 8332, 7223, 6073]}],
#                         {"showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mar ...

# %% [markdown]
# **Tweet Locations**

# %%
loc = df['Location'].value_counts().nlargest(n=10)

fig = px.bar(y=loc.values, x=loc.index, orientation='v', color=loc.index, text=loc.values)

fig.update_traces(texttemplate='%{text:.2s}', textposition='inside', marker_line_color='rgb(8,48,107)', marker_line_width=2)

fig.update_layout(width=800, showlegend=False, xaxis_title="Location", yaxis_title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="18c73ab0-6478-402b-b6fe-84bf1a6234d2" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18c73ab0-6478-402b-b6fe-84bf1a6234d2")) {
#                     Plotly.newPlot(
#                         '18c73ab0-6478-402b-b6fe-84bf1a6234d2',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=United States<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=United States", "marker": {"color": "#636efa", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=United States", "offsetgroup": "color=United States", "orientation": "v", "showlegend": true, "text": [603.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [603], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=London, England<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=London, England", "marker": {"color": "#EF553B", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=London, England", "offsetgroup": "color=London, England", "orientation": "v", "showlegend": true, "text": [568.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["London, England"], "xaxis": "x", "y": [568], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=London<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=London", "marker": {"color": "#00cc96", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=London", "offsetgroup": "color=London", "orientation": "v", "showlegend": true, "text": [565.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["London"], "xaxis": "x", "y": [565], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=New York, NY<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=New York, NY", "marker": {"color": "#ab63fa", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=New York, NY", "offsetgroup": "color=New York, NY", "orientation": "v", "showlegend": true, "text": [429.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["New York, NY"], "xaxis": "x", "y": [429], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=Washington, DC<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=Washington, DC", "marker": {"color": "#FFA15A", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=Washington, DC", "offsetgroup": "color=Washington, DC", "orientation": "v", "showlegend": true, "text": [411.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Washington, DC"], "xaxis": "x", "y": [411], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=United Kingdom<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=United Kingdom", "marker": {"color": "#19d3f3", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=United Kingdom", "offsetgroup": "color=United Kingdom", "orientation": "v", "showlegend": true, "text": [355.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [355], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=Los Angeles, CA<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=Los Angeles, CA", "marker": {"color": "#FF6692", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=Los Angeles, CA", "offsetgroup": "color=Los Angeles, CA", "orientation": "v", "showlegend": true, "text": [314.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Los Angeles, CA"], "xaxis": "x", "y": [314], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=India<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=India", "marker": {"color": "#B6E880", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=India", "offsetgroup": "color=India", "orientation": "v", "showlegend": true, "text": [283.0], "textposition": "i ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f

# %% [markdown]
# **Hashtags**

# %%
def extract_hash_tags(s):
    hashes = re.findall(r"#(\w+)", s)
    return " ".join(hashes)

df['hashtags'] = df['OriginalTweet'].apply(lambda x : extract_hash_tags(x))
allHashTags = list(df[(df['hashtags'] != None) & (df['hashtags'] != "")]['hashtags'])
allHashTags = [tag.lower() for tag in allHashTags]
hash_df = dict(Counter(allHashTags))
top_hash_df = pd.DataFrame(list(hash_df.items()),columns = ['word','count']).reset_index(drop=True).sort_values('count',ascending=False)[:10]

fig = px.bar(x=top_hash_df['word'],y=top_hash_df['count'],
       orientation='v',
       color=top_hash_df['word'],
       text=top_hash_df['count'],
       color_discrete_sequence= px.colors.qualitative.Bold)

fig.update_traces(texttemplate='%{text:.2s}', textposition='inside', marker_line_color='rgb(8,48,107)', marker_line_width=2)
fig.update_layout(width=800, showlegend=False, xaxis_title="Word", yaxis_title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ce8d1ff7-9a6e-4126-8c33-cf0b154dd7d8" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ce8d1ff7-9a6e-4126-8c33-cf0b154dd7d8")) {
#                     Plotly.newPlot(
#                         'ce8d1ff7-9a6e-4126-8c33-cf0b154dd7d8',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=coronavirus<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=coronavirus", "marker": {"color": "rgb(127, 60, 141)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=coronavirus", "offsetgroup": "color=coronavirus", "orientation": "v", "showlegend": true, "text": [3713.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["coronavirus"], "xaxis": "x", "y": [3713], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=covid_19<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=covid_19", "marker": {"color": "rgb(17, 165, 121)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=covid_19", "offsetgroup": "color=covid_19", "orientation": "v", "showlegend": true, "text": [1241.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["covid_19"], "xaxis": "x", "y": [1241], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=covid2019<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=covid2019", "marker": {"color": "rgb(57, 105, 172)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=covid2019", "offsetgroup": "color=covid2019", "orientation": "v", "showlegend": true, "text": [475.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["covid2019"], "xaxis": "x", "y": [475], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=coronavirus covid19<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=coronavirus covid19", "marker": {"color": "rgb(242, 183, 1)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=coronavirus covid19", "offsetgroup": "color=coronavirus covid19", "orientation": "v", "showlegend": true, "text": [372.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["coronavirus covid19"], "xaxis": "x", "y": [372], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=covid19 coronavirus<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=covid19 coronavirus", "marker": {"color": "rgb(231, 63, 116)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=covid19 coronavirus", "offsetgroup": "color=covid19 coronavirus", "orientation": "v", "showlegend": true, "text": [284.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["covid19 coronavirus"], "xaxis": "x", "y": [284], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=covid19<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=covid19", "marker": {"color": "rgb(128, 186, 90)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=covid19", "offsetgroup": "color=covid19", "orientation": "v", "showlegend": true, "text": [266.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["covid19"], "xaxis": "x", "y": [266], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=coronacrisis<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=coronacrisis", "marker": {"color": "rgb(230, 131, 16)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=coronacrisis", "offsetgroup": "color=coronacrisis", "orientation": "v", "showlegend": true, "text": [172.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["coronacrisis"], "xaxis": "x", "y": [172], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=covid<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=covid", "marker": {"color": "rgb(0, 134, 149)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=covid", "offsetgroup": "color=covid", "orientation" ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222

# %% [markdown]
# **Mentions**

# %%
# Get all mentions

def get_mentions(s):
    mentions = re.findall("(?<![@\w])@(\w{1,25})", s)
    return " ".join(mentions)
df['mentions'] = df['OriginalTweet'].apply(lambda x : get_mentions(x))

allMentions = list(df[(df['mentions'] != None) & (df['mentions'] != "")]['mentions'])
allMentions = [tag.lower() for tag in allMentions]
mentions_df = dict(Counter(allMentions))
top_mentions_df = pd.DataFrame(list(mentions_df.items()),columns = ['word','count']).reset_index(drop=True).sort_values('count',ascending=False)[:20]

fig = px.bar(x=top_mentions_df['word'],y=top_mentions_df['count'],
       orientation='v',
       color=top_mentions_df['word'],
       text=top_mentions_df['count'],
       color_discrete_sequence= px.colors.qualitative.Bold)

fig.update_traces(texttemplate='%{text:.2s}', textposition='inside', marker_line_color='rgb(8,48,107)', marker_line_width=2)
fig.update_layout(width=800, showlegend=False, xaxis_title="Word", yaxis_title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7aa66a0b-c25b-46c3-b2df-ef2651b0ff11" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7aa66a0b-c25b-46c3-b2df-ef2651b0ff11")) {
#                     Plotly.newPlot(
#                         '7aa66a0b-c25b-46c3-b2df-ef2651b0ff11',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=realdonaldtrump<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=realdonaldtrump", "marker": {"color": "rgb(127, 60, 141)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=realdonaldtrump", "offsetgroup": "color=realdonaldtrump", "orientation": "v", "showlegend": true, "text": [145.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["realdonaldtrump"], "xaxis": "x", "y": [145], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=youtube<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=youtube", "marker": {"color": "rgb(17, 165, 121)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=youtube", "offsetgroup": "color=youtube", "orientation": "v", "showlegend": true, "text": [78.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["youtube"], "xaxis": "x", "y": [78], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=amazon<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=amazon", "marker": {"color": "rgb(57, 105, 172)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=amazon", "offsetgroup": "color=amazon", "orientation": "v", "showlegend": true, "text": [73.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["amazon"], "xaxis": "x", "y": [73], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=tesco<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=tesco", "marker": {"color": "rgb(242, 183, 1)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=tesco", "offsetgroup": "color=tesco", "orientation": "v", "showlegend": true, "text": [69.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["tesco"], "xaxis": "x", "y": [69], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=borisjohnson<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=borisjohnson", "marker": {"color": "rgb(231, 63, 116)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=borisjohnson", "offsetgroup": "color=borisjohnson", "orientation": "v", "showlegend": true, "text": [63.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["borisjohnson"], "xaxis": "x", "y": [63], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=ftc<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=ftc", "marker": {"color": "rgb(128, 186, 90)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=ftc", "offsetgroup": "color=ftc", "orientation": "v", "showlegend": true, "text": [49.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["ftc"], "xaxis": "x", "y": [49], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=sainsburys<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=sainsburys", "marker": {"color": "rgb(230, 131, 16)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=sainsburys", "offsetgroup": "color=sainsburys", "orientation": "v", "showlegend": true, "text": [47.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["sainsburys"], "xaxis": "x", "y": [47], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "color=mckinsey<br>x=%{x}<br>y=%{y}<br>text=%{text}", "legendgroup": "color=mckinsey", "marker": {"color": "rgb(0, 134, 149)", "line": {"color": "rgb(8,48,107)", "width": 2}}, "name": "color=mckinsey", "offsetgroup": "color=mckinsey", "orientation": "v", "showlegend": true, "text": [35.0], "textposition": "inside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["mckinsey"], "xaxi ...

# %% [markdown]
# **Commonly Used Words**

# %%
temp = " ".join(df["OriginalTweet"].tolist())

wc = WordCloud(width=400, height=400, collocations= False, max_words= 50).generate(temp)

plt.figure(figsize=(12, 10))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# **Data description**

# %%
df.describe()

# %%
df['OriginalTweet']=df['OriginalTweet'].astype(str)
df['Sentiment']=df['Sentiment'].astype(str)

train['OriginalTweet']=train['OriginalTweet'].astype(str)
train['Sentiment']=train['Sentiment'].astype(str)

test['OriginalTweet']=test['OriginalTweet'].astype(str)
test['Sentiment']=test['Sentiment'].astype(str)

display(train.isnull().sum().sort_values(ascending=False))

# %%
class_df = df.groupby('Sentiment').count()['text'].reset_index().sort_values(by=' The hasta',ascending=False)
class_df.style.background_gradient(cmap='winter')
